# %%
# Import librearies for data manipulation and cleaning
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
# Load the data
data = pd.read_excel('data.xlsx')

# %%
# Show the first 5 rows of the data
data.head()
# Out:
#    ID Empleado Año de Nacimiento  Edad    Sexo  Sexo Num  \
# 0          123        1959-02-26    61  Hombre         1
# 1          119        2001-12-21    18   Mujer         0
# 2           85        1987-07-11    33   Mujer         0
# 3            5        1963-11-07    56  Hombre         1
# 4           67        1998-08-05    22  Hombre         1
#
#   Fecha Inicio de Contrato  Fecha Hoy  Antigüedad Meses  Antigüedad Años  \
# 0               2016-03-16 2020-10-14         55.766667         4.647222
# 1               2020-04-27 2020-10-14          5.666667         0.472222
# 2               2014-08-02 2020-10-14         75.500000         6.291667
# 3               2015-09-08 2020-10-14         62.100000         5.175000
# 4               2019-02-06 2020-10-14         20.533333         1.711111
#
#   Formación Oficial Reglada  ...  Puntuación 360 Neglicencias/Sanciones  \
# 0               Grado Medio  ...             NaN                      5
# 1             Universitaria  ...             NaN                      5
# 2               Grado Medio  ...             6.0                      4
# 3              Bachillerato  ...             NaN                      4
# 4                       ESO  ...             NaN                      4
#
#    Nuevas contrataciones 2020 Valoración liderazgo 2019 (sobre 10)  \
# 0                           0                                  NaN
# 1                           1                                  NaN
# 2                           0                                 5.66
# 3                           0                                  NaN
# 4                           0                                  NaN
#
#   Valoración liderazgo 2020 (sobre 10)  Personas a cargo 2020  \
# 0                                  NaN                    NaN
# 1                                  NaN                    NaN
# 2                                 6.46                    3.0
# 3                                  NaN                    NaN
# 4                                  NaN                    NaN
#
#    Engagement individual 2020(sobre 6)  Engagement equipo 2020(sobre 6) NPS  \
# 0                                  NaN                              NaN   6
# 1                                  NaN                              NaN   7
# 2                                 5.15                              NaN  10
# 3                                  NaN                              NaN   4
# 4                                  NaN                              NaN   4
#
#   Evaluación Desempeño
# 0                    6
# 1                    8
# 2                   10
# 3                    7
# 4                    5
#
# [5 rows x 45 columns]

# %%
# Show the last 5 rows of the data
data.tail()
# Out:
#      ID Empleado Año de Nacimiento  Edad    Sexo  Sexo Num  \
# 306           76        1983-07-15    37   Mujer         0
# 307           89        1997-09-13    23  Hombre         1
# 308           93        1979-07-11    41  Hombre         1
# 309          115        1992-12-26    27  Hombre         1
# 310          131        1965-01-29    55  Hombre         1
#
#     Fecha Inicio de Contrato  Fecha Hoy  Antigüedad Meses  Antigüedad Años  \
# 306               2018-10-10 2020-10-14         24.500000         2.041667
# 307               2019-07-12 2020-10-14         15.333333         1.277778
# 308               2015-07-05 2020-10-14         64.266667         5.355556
# 309               2017-05-24 2020-10-14         41.300000         3.441667
# 310               2001-01-11 2020-10-14        240.533333        20.044444
#
#     Formación Oficial Reglada  ...  Puntuación 360 Neglicencias/Sanciones  \
# 306                       ESO  ...             9.0                      0
# 307                       ESO  ...             7.0                      0
# 308               Grado Medio  ...             9.0                      0
# 309               Grado Medio  ...             7.0                      0
# 310                       ESO  ...             8.0                      0
#
#      Nuevas contrataciones 2020 Valoración liderazgo 2019 (sobre 10)  \
# 306                           0                                 7.61
# 307                           0                                 8.27
# 308                           0                                 7.47
# 309                           0                                 8.78
# 310                           0                                 8.75
#
#     Valoración liderazgo 2020 (sobre 10)  Personas a cargo 2020  \
# 306                                 7.41                    8.0
# 307                                 8.07                    8.0
# 308                                 7.30                    8.0
# 309                                 8.70                    7.0
# 310                                 8.70                    7.0
#
#      Engagement individual 2020(sobre 6)  Engagement equipo 2020(sobre 6) NPS  \
# 306                                 3.32                             3.69  10
# 307                                 3.99                             3.40   6
# 308                                 3.37                             3.28   6
# 309                                 4.01                             4.04   4
# 310                                 3.58                             3.02   5
#
#     Evaluación Desempeño
# 306                    7
# 307                    7
# 308                    9
# 309                    6
# 310                    6
#
# [5 rows x 45 columns]

# %%
# Show the shape of the data
print("The data has {} rows and {} columns".format(data.shape[0], data.shape[1]))
# Out:
# The data has 311 rows and 45 columns

# %%
# Show the information of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 45 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   ID Empleado                           311 non-null    int64
#  1   Año de Nacimiento                     311 non-null    datetime64[ns]
#  2   Edad                                  311 non-null    int64
#  3   Sexo                                  311 non-null    object
#  4   Sexo Num                              311 non-null    int64
#  5   Fecha Inicio de Contrato              311 non-null    datetime64[ns]
#  6   Fecha Hoy                             311 non-null    datetime64[ns]
#  7   Antigüedad Meses                      311 non-null    float64
#  8   Antigüedad Años                       311 non-null    float64
#  9   Formación Oficial Reglada             311 non-null    object
#  10  Formación Oficial Num                 311 non-null    int64
#  11  ESTADO CIVIL                          234 non-null    object
#  12  HIJOS                                 282 non-null    float64
#  13  % MINUSVALÍA                          304 non-null    object
#  14  Categoría laboral                     311 non-null    object
#  15  Cat Lab num                           311 non-null    int64
#  16  Horas Jornada                         310 non-null    float64
#  17  FTE                                   311 non-null    float64
#  18  Causa Abs                             81 non-null     object
#  19  Fecha de baja (Abs)                   81 non-null     datetime64[ns]
#  20  Fecha Alta (Abs)                      81 non-null     datetime64[ns]
#  21  Días de Trabajo Perdido (Abs)         311 non-null    int64
#  22  Departamento                          311 non-null    object
#  23  Departamento Num                      311 non-null    int64
#  24  Rotación Externa                      311 non-null    int64
#  25  Fecha Rotación Externa                64 non-null     datetime64[ns]
#  26   Motivo Rotación                      64 non-null     object
#  27  Rotación Interna                      311 non-null    int64
#  28  Fecha Rotación Interna                37 non-null     datetime64[ns]
#  29  Motivo Rotación Interna               37 non-null     object
#  30  Salario Anual Inicial 2020            311 non-null    int64
#  31  Salario Anual Actual 2020             311 non-null    int64
#  32  Diferencia Salario                    311 non-null    int64
#  33  Experiencia previa (meses)            311 non-null    int64
#  34  Horas de formación recibidas          311 non-null    int64
#  35  Puntuación 360                        64 non-null     float64
#  36  Neglicencias/Sanciones                311 non-null    int64
#  37  Nuevas contrataciones 2020            311 non-null    int64
#  38  Valoración liderazgo 2019 (sobre 10)  64 non-null     float64
#  39  Valoración liderazgo 2020 (sobre 10)  64 non-null     float64
#  40  Personas a cargo 2020                 64 non-null     float64
#  41  Engagement individual 2020(sobre 6)   64 non-null     float64
#  42  Engagement equipo 2020(sobre 6)       56 non-null     float64
#  43  NPS                                   311 non-null    int64
#  44  Evaluación Desempeño                  311 non-null    int64
# dtypes: datetime64[ns](7), float64(11), int64(18), object(9)
# memory usage: 109.5+ KB

# %%
# Show the summary statistics of the data
data.describe()
# Out:
#        ID Empleado              Año de Nacimiento        Edad    Sexo Num  \
# count   311.000000                            311  311.000000  311.000000
# mean    156.000000  1978-05-26 06:56:43.215434080   41.919614    0.514469
# min       1.000000            1956-01-25 00:00:00   18.000000    0.000000
# 25%      78.500000            1967-05-01 12:00:00   31.000000    0.000000
# 50%     156.000000            1977-04-11 00:00:00   43.000000    1.000000
# 75%     233.500000            1989-09-01 12:00:00   53.000000    1.000000
# max     311.000000            2002-01-13 00:00:00   64.000000    1.000000
# std      89.922189                            NaN   13.194695    0.500596
#
#             Fecha Inicio de Contrato            Fecha Hoy  Antigüedad Meses  \
# count                            311                  311        311.000000
# mean   2014-04-02 01:18:42.829582080  2020-10-14 00:00:00         79.564845
# min              2000-01-14 00:00:00  2020-10-14 00:00:00          0.600000
# 25%              2013-01-11 00:00:00  2020-10-14 00:00:00         35.833333
# 50%              2015-09-08 00:00:00  2020-10-14 00:00:00         62.100000
# 75%              2017-11-04 00:00:00  2020-10-14 00:00:00         94.433333
# max              2020-09-26 00:00:00  2020-10-14 00:00:00        252.633333
# std                              NaN                  NaN         65.698471
#
#        Antigüedad Años  Formación Oficial Num       HIJOS  ...  \
# count       311.000000             311.000000  282.000000  ...
# mean          6.630404               2.607717    0.634752  ...
# min           0.050000               1.000000    0.000000  ...
# 25%           2.986111               1.000000    0.000000  ...
# 50%           5.175000               2.000000    0.000000  ...
# 75%           7.869444               4.000000    1.000000  ...
# max          21.052778               6.000000    4.000000  ...
# std           5.474873               1.515662    0.883578  ...
#
#        Puntuación 360  Neglicencias/Sanciones  Nuevas contrataciones 2020  \
# count       64.000000              311.000000                  311.000000
# mean         6.859375                0.205788                    0.096463
# min          5.000000                0.000000                    0.000000
# 25%          5.750000                0.000000                    0.000000
# 50%          7.000000                0.000000                    0.000000
# 75%          8.000000                0.000000                    0.000000
# max          9.000000                5.000000                    1.000000
# std          1.435018                0.784589                    0.295701
#
#       Valoración liderazgo 2019 (sobre 10)  \
# count                            64.000000
# mean                              6.940000
# min                               4.140000
# 25%                               6.272500
# 50%                               7.180000
# 75%                               7.822500
# max                               8.780000
# std                               1.220866
#
#       Valoración liderazgo 2020 (sobre 10)  Personas a cargo 2020  \
# count                            64.000000              64.000000
# mean                              7.383750               4.937500
# min                               4.200000               1.000000
# 25%                               6.805000               2.000000
# 50%                               7.530000               3.000000
# 75%                               8.050000               8.000000
# max                               8.700000              28.000000
# std                               0.940462               5.048574
#
#        Engagement individual 2020(sobre 6)  Engagement equipo 2020(sobre 6)  \
# count                            64.000000                        56.000000
# mean                              4.489844                         4.051905
# min                               3.090000                         3.010000
# 25%                               3.772500                         3.580000
# 50%                               4.610000                         3.791250
# 75%                               5.122500                         4.589375
# max                               5.870000                         5.770000
# std                               0.817119                         0.763102
#
#               NPS  Evaluación Desempeño
# count  311.000000            311.000000
# mean     7.122186              7.614148
# min      4.000000              5.000000
# 25%      6.000000              6.000000
# 50%      7.000000              8.000000
# 75%      9.000000              9.000000
# max     10.000000             10.000000
# std      1.983282              1.705492
#
# [8 rows x 36 columns]

# %%
# Check duplicates
print("the data has {} duplicates".format(data.duplicated().sum()))
# Out:
# the data has 0 duplicates

# %%
# Check missing values
print("The data has {} missing values".format(data.isnull().sum()))
# Out:
# The data has ID Empleado                               0
# Año de Nacimiento                         0
# Edad                                      0
# Sexo                                      0
# Sexo Num                                  0
# Fecha Inicio de Contrato                  0
# Fecha Hoy                                 0
# Antigüedad Meses                          0
# Antigüedad Años                           0
# Formación Oficial Reglada                 0
# Formación Oficial Num                     0
# ESTADO CIVIL                             77
# HIJOS                                    29
# % MINUSVALÍA                              7
# Categoría laboral                         0
# Cat Lab num                               0
# Horas Jornada                             1
# FTE                                       0
# Causa Abs                               230
# Fecha de baja (Abs)                     230
# Fecha Alta (Abs)                        230
# Días de Trabajo Perdido (Abs)             0
# Departamento                              0
# Departamento Num                          0
# Rotación Externa                          0
# Fecha Rotación Externa                  247
#  Motivo Rotación                        247
# Rotación Interna                          0
# Fecha Rotación Interna                  274
# Motivo Rotación Interna                 274
# Salario Anual Inicial 2020                0
# Salario Anual Actual 2020                 0
# Diferencia Salario                        0
# Experiencia previa (meses)                0
# Horas de formación recibidas              0
# Puntuación 360                          247
# Neglicencias/Sanciones                    0
# Nuevas contrataciones 2020                0
# Valoración liderazgo 2019 (sobre 10)    247
# Valoración liderazgo 2020 (sobre 10)    247
# Personas a cargo 2020                   247
# Engagement individual 2020(sobre 6)     247
# Engagement equipo 2020(sobre 6)         255
# NPS                                       0
# Evaluación Desempeño                      0
# dtype: int64 missing values

# %%
# Remove columns with many missing values
threshold = 0.5  # Threshold for allowed missing values (50%)
for column in data.columns:
    if data[column].isnull().sum() / len(data) > threshold:
        data.drop(column, axis=1, inplace=True)

# Replace remaining missing values with mean or mode
for column in data.columns:
    if data[column].dtype == 'object':
        # Replace missing values with mode for categorical columns
        data[column].fillna(data[column].mode()[0], inplace=True)
    else:
        # Replace missing values with mean for numerical columns
        data[column].fillna(data[column].mean(), inplace=True)

# Verify the changes and show dropped columns
print("The data has {} rows and {} columns after cleaning".format(data.shape[0], data.shape[1]))
print("The data has {} missing values after cleaning".format(data.isnull().sum().sum()))
print("Columns dropped: {}".format(set(data.columns).symmetric_difference(set(pd.read_excel('data.xlsx').columns))))

# Show the first 5 rows of the cleaned data
data.head()
# Out:
# The data has 311 rows and 32 columns after cleaning
# The data has 0 missing values after cleaning
# Columns dropped: {'Engagement equipo 2020(sobre 6)', 'Motivo Rotación Interna', 'Fecha Alta (Abs)', 'Fecha Rotación Interna', 'Valoración liderazgo 2020 (sobre 10)', 'Fecha Rotación Externa', 'Puntuación 360', 'Fecha de baja (Abs)', 'Personas a cargo 2020', 'Engagement individual 2020(sobre 6)', 'Valoración liderazgo 2019 (sobre 10)', ' Motivo Rotación', 'Causa Abs'}
#    ID Empleado Año de Nacimiento  Edad    Sexo  Sexo Num  \
# 0          123        1959-02-26    61  Hombre         1
# 1          119        2001-12-21    18   Mujer         0
# 2           85        1987-07-11    33   Mujer         0
# 3            5        1963-11-07    56  Hombre         1
# 4           67        1998-08-05    22  Hombre         1
#
#   Fecha Inicio de Contrato  Fecha Hoy  Antigüedad Meses  Antigüedad Años  \
# 0               2016-03-16 2020-10-14         55.766667         4.647222
# 1               2020-04-27 2020-10-14          5.666667         0.472222
# 2               2014-08-02 2020-10-14         75.500000         6.291667
# 3               2015-09-08 2020-10-14         62.100000         5.175000
# 4               2019-02-06 2020-10-14         20.533333         1.711111
#
#   Formación Oficial Reglada  ...  Rotación Interna Salario Anual Inicial 2020  \
# 0               Grado Medio  ...                 0                      26496
# 1             Universitaria  ...                 0                      17720
# 2               Grado Medio  ...                 0                      29686
# 3              Bachillerato  ...                 0                      19197
# 4                       ESO  ...                 0                      18864
#
#    Salario Anual Actual 2020 Diferencia Salario Experiencia previa (meses)  \
# 0                      26496                  0                        284
# 1                      17720                  0                         47
# 2                      29686                  0                        324
# 3                      19197                  0                        114
# 4                      18864                  0                         18
#
#    Horas de formación recibidas  Neglicencias/Sanciones  \
# 0                             0                       5
# 1                             0                       5
# 2                            25                       4
# 3                             6                       4
# 4                            18                       4
#
#    Nuevas contrataciones 2020  NPS Evaluación Desempeño
# 0                           0    6                    6
# 1                           1    7                    8
# 2                           0   10                   10
# 3                           0    4                    7
# 4                           0    4                    5
#
# [5 rows x 32 columns]

# %%
# Boxplots para detectar outliers
print("\nBoxplots para detectar outliers:")

# Configuración de estilo de Seaborn
sns.set(style="whitegrid")

# Generar boxplots para cada columna numérica
for column in data.select_dtypes(include=['float64', 'int64']).columns:
    plt.figure(figsize=(12, 6))
    sns.boxplot(x=data[column], palette="Set2")
    plt.title(f'Boxplot de {column}', fontsize=15)
    plt.xlabel(column, fontsize=12)
    plt.ylabel('Valores', fontsize=12)
    plt.show()
# Out:
# Boxplots para detectar outliers:

# %%
# Correlation matrix includes only numerical columns and without the values

# Set Seaborn style
sns.set_style(style="white")

# Generate correlation matrix
plt.figure(figsize=(12, 6))
sns.heatmap(data.select_dtypes(include=['float64', 'int64']).corr(), annot=False, cmap='coolwarm')
plt.title('Correlation Matrix', fontsize=15)
plt.show()

# %% [markdown]
# ## Correlation Matrix Analysis
#
# The correlation matrix shows the relationship between different variables in the dataset. Here are some key points:
#
# ### Strong Positive Correlations:
# - **💼 Salario Anual Inicial 2020 and Salario Anual Actual 2020** have a very high correlation (0.995), which is expected since the current salary is likely based on the initial salary.
# - **⏰ Horas Jornada and FTE** have a very high correlation (0.977), indicating that these two variables are closely related.
# - **📊 Cat Lab num and Salario Anual Inicial 2020** have a high correlation (0.898), suggesting that the job category significantly influences the initial salary.
#
# ### Strong Negative Correlations:
# - **👶 Nuevas contrataciones 2020 and Edad** have a moderate negative correlation (-0.354), which could indicate that new hires tend to be younger.
# - **📉 Nuevas contrataciones 2020 and Antigüedad Meses** have a moderate negative correlation (-0.371), which is logical since new employees have less tenure.
#
# ### Moderate Correlations:
# - **🎓 Formación Oficial Num and Rotación Interna** have a moderate correlation (0.535), suggesting that official training may be related to internal turnover.
# - **📚 Horas de formación recibidas and Salario Anual Inicial 2020** have a moderate correlation (0.787), indicating that more training hours may be associated with a higher initial salary.
#
# ### General Observations:
# - Most correlations between **🆔 ID Empleado** and other variables are low, which is expected since ID Empleado is an identifier variable.
# - **📈 Evaluación Desempeño** does not show strong correlations with any other variable, which could indicate that performance is not strongly influenced by the available variables in the dataset.

# %%
# Save the cleaned data
data.to_excel('data_cleaned.xlsx', index=False)
